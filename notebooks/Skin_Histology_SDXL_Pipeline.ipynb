# %% [markdown]
# # Skin Histology SDXL Inpainting Pipeline
#
# Notebook companion for the DVC pipeline in `skin_histology_sdxl_collab`.

# %%
# %cd /home/fertroll10/Documents/ML/skin_histology_sdxl_collab

# %% [markdown]
# ## 1) Fetch manifest and download Histo-Seg

# %%
# !dvc repro fetch_histo_seg_manifest
# !dvc repro download_histo_seg_dataset

# %% [markdown]
# ## 2) Build paired CSV (image + mask)

# %%
# !dvc repro build_histoseg_pairs_csv

# %% [markdown]
# ## 3) Render runtime configs from params.yaml
#
# Fill `params.yaml` model paths first (`models.sdxl_base_model`, `models.classifier_checkpoint`, `models.kohya_scripts_dir`).

# %%
# !dvc repro render_runtime_configs

# %% [markdown]
# ## 4) Build Grad-CAM masks
#
# Grad-CAM uses paths from `params.yaml`.

# %%
# !dvc repro build_gradcam_masks_for_skin

# %% [markdown]
# ## 5) Train SDXL LoRA phases

# %%
# !dvc repro train_skin_lora_phase1
# !dvc repro train_skin_lora_phase2
# !dvc repro train_skin_lora_phase3
